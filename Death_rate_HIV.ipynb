# %%
# Import the modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\Death rate for HIv.csv")
df
# Out:
#      Year   Sex        Age    Value    Upper    Lower
# 0    2000  Both   Age 0-14  340,000  220,000  510,000
# 1    2000  Both   Age 0-19  350,000  230,000  530,000
# 2    2000  Both    Age 0-4  300,000  200,000  450,000
# 3    2000  Both    Age 0-9  320,000  210,000  490,000
# 4    2000  Both  Age 10-14   12,000    7,800   18,000
# ..    ...   ...        ...      ...      ...      ...
# 499  2020  Male    Age 0-9   43,000   29,000   68,000
# 500  2020  Male  Age 10-14    7,500    5,200   12,000
# 501  2020  Male  Age 10-19   16,000   12,000   23,000
# 502  2020  Male  Age 15-19    8,700    5,800   13,000
# 503  2020  Male    Age 5-9    4,800    3,300    7,600
#
# [504 rows x 6 columns]

# %%
plt.rcParams["figure.figsize"] = (25,25)
df.plot(kind='scatter',x='Age',y='Value') # scatter plot
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Value'>

# %%
plt.rcParams["figure.figsize"] = (25,25)
df.plot(kind='scatter',x='Year',y='Value') # scatter plot
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>
