# %%
# Import the modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\Lost_parents.csv")
df
# Out:
#     Year       Number
# 0   2000  157,000,000
# 1   2001  157,600,000
# 2   2002  158,000,000
# 3   2003  158,100,000
# 4   2004  157,900,000
# 5   2005  157,500,000
# 6   2006  156,800,000
# 7   2007  156,000,000
# 8   2008  155,400,000
# 9   2009  154,900,000
# 10  2010  154,400,000
# 11  2011  153,900,000
# 12  2012  153,300,000
# 13  2013  152,600,000
# 14  2014  152,000,000
# 15  2015  151,400,000
# 16  2016  150,800,000
# 17  2017  150,100,000
# 18  2018  149,400,000
# 19  2019  148,700,000
# 20  2020  148,100,000
# 21  2000    8,630,000
# 22  2001    9,790,000
# 23  2002   10,900,000
# 24  2003   12,100,000
# 25  2004   13,200,000
# 26  2005   14,200,000
# 27  2006   15,000,000
# 28  2007   15,800,000
# 29  2008   16,400,000
# 30  2009   16,800,000
# 31  2010   17,100,000
# 32  2011   17,300,000
# 33  2012   17,500,000
# 34  2013   17,400,000
# 35  2014   17,400,000
# 36  2015   17,200,000
# 37  2016   17,000,000
# 38  2017   16,700,000
# 39  2018   16,400,000
# ...

# %%
# Make a list of columns
columns = ['Year','Number']

# Read a CSV file
df = pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\Lost_parents.csv", usecols=columns)

# Plot the lines
df.plot()

plt.show()
