# %%
# Import the modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\HIV in child.csv")
df
# Out:
#      Year     Sex        Age  value  lower  upper
# 0    2000    Both   Age 0-14   0.85   0.56   1.34
# 1    2000    Both  Age 10-19   0.66   0.19   1.31
# 2    2000  Female   Age 0-14   0.87   0.57   1.36
# 3    2000  Female  Age 10-19   1.01   0.20   1.95
# 4    2000    Male   Age 0-14   0.84   0.55   1.32
# ..    ...     ...        ...    ...    ...    ...
# 121  2020    Both  Age 10-19   0.25   0.07   0.50
# 122  2020  Female   Age 0-14   0.23   0.15   0.36
# 123  2020  Female  Age 10-19   0.40   0.08   0.78
# 124  2020    Male   Age 0-14   0.22   0.15   0.35
# 125  2020    Male  Age 10-19   0.11   0.02   0.29
#
# [126 rows x 6 columns]

# %%
#shorting data (0-14)

# %%
# sort data frame
#csvData.sort_values([csvData.columns[3]],
#                   axis=0,
#                    ascending=[True],
#                    inplace=True)  
# displaying sorted data frame
#print("\nAfter sorting:")
#print(csvData)


#printing the data for child only age between 0-14
df1= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\HIV in child-.csv")
df1
# Out:
#     Year     Sex       Age  value  lower  upper
# 0   2000    Both  Age 0-14   0.85   0.56   1.34
# 1   2000  Female  Age 0-14   0.87   0.57   1.36
# 2   2000    Male  Age 0-14   0.84   0.55   1.32
# 3   2001    Both  Age 0-14   0.85   0.55   1.33
# 4   2001  Female  Age 0-14   0.86   0.56   1.35
# ..   ...     ...       ...    ...    ...    ...
# 58  2019  Female  Age 0-14   0.24   0.15   0.37
# 59  2019    Male  Age 0-14   0.23   0.15   0.36
# 60  2020    Both  Age 0-14   0.23   0.15   0.36
# 61  2020  Female  Age 0-14   0.23   0.15   0.36
# 62  2020    Male  Age 0-14   0.22   0.15   0.35
#
# [63 rows x 6 columns]

# %%
  #shorting data (Age 10-19)

# %%
# sort data frame
#csvData.sort_values([csvData.columns[3]],
#                   axis=0,
#                    descending=[True],
#                    inplace=True)  
# displaying sorted data frame
#print("\nAfter sorting:")
#print(csvData)


#printing the data for child only age between 10 - 19
df2= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\HIV in child+.csv")
df2
# Out:
#     Year     Sex        Age  value  lower  upper
# 0   2000    Both  Age 10-19   0.66   0.19   1.31
# 1   2000  Female  Age 10-19   1.01   0.20   1.95
# 2   2000    Male  Age 10-19   0.32   0.06   0.84
# 3   2001    Both  Age 10-19   0.62   0.17   1.23
# 4   2001  Female  Age 10-19   0.95   0.19   1.83
# ..   ...     ...        ...    ...    ...    ...
# 58  2019  Female  Age 10-19   0.44   0.09   0.84
# 59  2019    Male  Age 10-19   0.12   0.02   0.31
# 60  2020    Both  Age 10-19   0.25   0.07   0.50
# 61  2020  Female  Age 10-19   0.40   0.08   0.78
# 62  2020    Male  Age 10-19   0.11   0.02   0.29
#
# [63 rows x 6 columns]

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['value', 'lower', 'upper']

# Read a CSV file
df = pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\HIV in child-.csv", usecols=columns)
plt.rcParams["figure.figsize"] = (20,10)
# Plot the lines
df.plot()

plt.show()

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['value', 'lower', 'upper']

# Read a CSV file
df = pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\HIV in child+.csv", usecols=columns)
plt.rcParams["figure.figsize"] = (20,10)
# Plot the lines
df.plot()

plt.show()
