# %%
# Import the modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\New HIV cases every year.csv")
df
# Out:
#      Year        Age    Value    Lower      Upper
# 0    2000   Age 0-14  520,000  340,000    820,000
# 1    2000   Age 0-19  890,000  450,000  1,560,000
# 2    2000    Age 0-4  520,000  340,000    820,000
# 3    2000    Age 0-9  520,000  340,000    820,000
# 4    2000  Age 10-19  370,000  100,000    740,000
# ..    ...        ...      ...      ...        ...
# 373  2020   Age 0-19  110,000   57,000    210,000
# 374  2020    Age 0-4   78,000   51,000    120,000
# 375  2020    Age 0-9   78,000   51,000    120,000
# 376  2020  Age 10-19   35,000    6,200     92,000
# 377  2020  Age 15-19   35,000    6,200     92,000
#
# [378 rows x 5 columns]

# %%
plt.rcParams["figure.figsize"] = (25,25)
df.plot(kind='scatter',x='Age',y='Value') # scatter plot
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Value'>

# %%
plt.rcParams["figure.figsize"] = (25,25)
df.plot(kind='scatter',x='Year',y='Value') # scatter plot
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>
