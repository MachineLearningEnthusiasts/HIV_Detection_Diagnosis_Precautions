# %%
# Import the modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\ART drugs Effectivity among people.csv")
df
# Out:
#     Year     Sex  avg success  lower rate  Higher rate
# 0   2010    Both         10.6         7.8         15.5
# 1   2010  Female          9.3         6.6         15.4
# 2   2010    Male         12.7         9.4         16.7
# 3   2011    Both         13.6        10.0         19.8
# 4   2011  Female         12.3         8.7         20.3
# 5   2011    Male         15.7        11.7         20.7
# 6   2012    Both         16.9        12.5         24.6
# 7   2012  Female         15.6        11.1         26.0
# 8   2012    Male         18.8        14.0         24.8
# 9   2013    Both         20.7        15.3         30.1
# 10  2013  Female         19.7        14.0         32.7
# 11  2013    Male         22.1        16.5         29.2
# 12  2014    Both         24.6        18.2         35.9
# 13  2014  Female         23.8        17.0         39.7
# 14  2014    Male         25.6        19.3         33.9
# 15  2015    Both         28.9        21.4         42.2
# ...

# %%
df.plot(kind='scatter',x='Sex',y='avg success') # scatter plot
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='avg success'>

# %%
plt.rcParams["figure.figsize"] = (10,5)
df.plot(kind='scatter',x='Year',y='avg success') # scatter plot
# Out:
# <AxesSubplot:xlabel='Year', ylabel='avg success'>
