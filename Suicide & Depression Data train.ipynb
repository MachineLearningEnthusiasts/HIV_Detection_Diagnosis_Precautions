# %%
# Import the modules
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\Suicide & depression.csv")
df
# Out:
#                                Area     Sex  Depression/suicidial throughts
# 0      Middle East and North Africa  Female                            63.8
# 1      Middle East and North Africa    Male                            64.3
# 2                        South Asia  Female                            40.0
# 3                        South Asia    Male                            40.5
# 4           West and Central Africa  Female                            41.4
# 5           West and Central Africa    Male                            42.4
# 6       Latin America and Caribbean  Female                            45.3
# 7       Latin America and Caribbean    Male                            45.5
# 8           West and Central Africa  Female                            28.5
# 9           West and Central Africa  Female                            29.8
# 10      Eastern and Southern Africa  Female                            61.3
# ...

# %%
#female dataset

# %%
df = pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\Suicide & depression.csv")
df_2 = df[2: :2]
df_2
# Out:
#                                Area     Sex  Depression/suicidial throughts
# 2                        South Asia  Female                            40.0
# 4           West and Central Africa  Female                            41.4
# 6       Latin America and Caribbean  Female                            45.3
# 8           West and Central Africa  Female                            28.5
# 10      Eastern and Southern Africa  Female                            61.3
# 12          West and Central Africa  Female                            51.7
# 14     Middle East and North Africa  Female                            79.0
# 16  Eastern Europe and Central Asia  Female                            81.5
# 18            East Asia and Pacific  Female                            81.0
# 20      Eastern and Southern Africa  Female                            52.0
# 22          West and Central Africa  Female                            75.2
# ...

# %%
plt.rcParams["figure.figsize"] = (20,5)
df_2.plot(x='Area',y='Depression/suicidial throughts')  # plots all columns against index
df_2.plot(kind='scatter',x='Area',y='Depression/suicidial throughts') # scatter plot
df_2.plot(kind='density',x='Area',y='Depression/suicidial throughts')  # estimate density function
df_2.plot(kind='hist',x='Area',y='Depression/suicidial throughts')  # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#male dataset

# %%
df = pd.read_csv("C:\\Users\\SOUMYADIP MALLICK\\OneDrive\\Desktop\\HIV & AIDS\\Suicide & depression.csv")
df_3 = df[1: :2]
df_3
# Out:
#                                Area     Sex  Depression/suicidial throughts
# 1      Middle East and North Africa    Male                            64.3
# 3                        South Asia    Male                            40.5
# 5           West and Central Africa    Male                            42.4
# 7       Latin America and Caribbean    Male                            45.5
# 9           West and Central Africa  Female                            29.8
# 11      Eastern and Southern Africa    Male                            63.9
# 13          West and Central Africa    Male                            52.0
# 15     Middle East and North Africa    Male                            80.7
# 17  Eastern Europe and Central Asia    Male                            82.1
# 19            East Asia and Pacific    Male                            81.5
# 21      Eastern and Southern Africa    Male                            58.5
# ...

# %%
plt.rcParams["figure.figsize"] = (20,5)
df_3.plot(x='Area',y='Depression/suicidial throughts')  # plots all columns against index
df_3.plot(kind='scatter',x='Area',y='Depression/suicidial throughts') # scatter plot
df_3.plot(kind='density',x='Area',y='Depression/suicidial throughts')  # estimate density function
df_3.plot(kind='hist',x='Area',y='Depression/suicidial throughts')  # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#combined dataset

# %%
plt.rcParams["figure.figsize"] = (20,5)
df.plot(x='Area',y='Depression/suicidial throughts')  # plots all columns against index
df.plot(kind='scatter',x='Area',y='Depression/suicidial throughts') # scatter plot
df.plot(kind='density',x='Area',y='Depression/suicidial throughts')  # estimate density function
df.plot(kind='hist',x='Area',y='Depression/suicidial throughts')  # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>
